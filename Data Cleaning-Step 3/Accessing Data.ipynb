# %%
import pandas as pd

# %%
patients = pd.read_csv('patients.csv')
treatments = pd.read_csv('treatments.csv')
adverse_reaction = pd.read_csv('adverse_reaction.csv')

# %%
print(patients.shape)
print(treatments.shape)
print(adverse_reaction.shape)
# Out:
# (503, 14)
# (280, 7)
# (34, 3)

# %%
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
treatments.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
adverse_reaction.head()
# Out:
#   given_name     surname           adverse_reaction
# 0      berta  napolitani  injection site discomfort
# 1       lena        baer               hypoglycemia
# 2     joseph         day               hypoglycemia
# 3     flavia  fiorentino                      cough
# 4    manouck     wubbels          throat irritation

# %%
patients.info() # 12 columns have missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
patients[patients['address'].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
patients.sample(5)  # phone numbers are stored in different format
# Out:
#      patient_id assigned_sex given_name    surname                 address  \
# 190         191         male     Regolo      Nucci      3595 Stuart Street
# 295         296         male     Albino  Schiavone  3113 Timber Ridge Road
# 114         115         male     Yunadi   Barsukov    2784 Turkey Pen Road
# 271         272         male     Russom    Amanuel      3942 Jerome Avenue
# 96           97       female      Nasim      Salib       3161 Fantages Way
#
#              city       state  zip_code        country  \
# 190      Gibsonia          PA   15044.0  United States
# 295    Sacramento  California   95814.0  United States
# 114     Manhattan    New York   10016.0  United States
# 271      Edinburg          TX   78539.0  United States
# 96   Presque Isle          ME    4769.0  United States
#
#                                        contact  birthdate  weight  height  \
# 190    RegoloNucci@einrot.com+1 (724) 449-6928  9/15/1935   213.0      67
# ...

# %%
patients['address'].duplicated() # duplicate address
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 498    False
# 499    False
# 500    False
# 501    False
# 502     True
# Name: address, Length: 503, dtype: bool

# %%
patients[patients['address'].duplicated()]
# Out:
#      patient_id assigned_sex given_name     surname             address  \
# 29           30         male       Jake    Jakobsen   648 Old Dear Lane
# 219         220         male         Mỹ       Quynh                 NaN
# 229         230         male       John         Doe     123 Main Street
# 230         231       female  Elisabeth     Knudsen                 NaN
# 234         235       female    Martina   Tománková                 NaN
# 237         238         male       John         Doe     123 Main Street
# 242         243         male       John     O'Brian                 NaN
# 244         245         male       John         Doe     123 Main Street
# 249         250         male   Benjamin      Mehler                 NaN
# 251         252         male       John         Doe     123 Main Street
# 257         258         male        Jin        Kung                 NaN
# 264         265       female   Wafiyyah      Asfour                 NaN
# ...

# %%
treatments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
treatments.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
adverse_reaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   given_name        34 non-null     object
#  1   surname           34 non-null     object
#  2   adverse_reaction  34 non-null     object
# dtypes: object(3)
# memory usage: 944.0+ bytes

# %%
# finiding qualities issues in data

# %% [markdown]
# # QUALITY
#
# [Completness,Validity,Accuracy,Consistency]
#
# - PATIENTS
#   1. zip code is stored in decimal format [v]
#   2. certain zip code are of 4 digits [v]
#   3. for the state col both full and short names are used [IC]
#   4. missing values for 12 patitents in contact details [C]
#   5. incorrect datatypes for assigned_sex nd birthdate cols  [?]
#   6. errorneous data for weight and height [A]
#   7. inconsistent way of storing phone numbers in contact         col [C]
#   8. duplicated data in dataset [C]
#
#
# - TREATMENTS
#   1. hbalc_change col has missing values [C]
#   2. novodra and auralin has u attached to numbers [C]
#   3. only 280 rows are  present instead of 350 [C]
#   4. incorrect datatype for novodra and auralin [V]
#   5. errorneous data for hbalc change 9 instead of 4 [A]
#   6. use of '-' instead of 'NaN' in novodra and auralin col
#   [C]
#
#
# - ADVERSE REACTIONS
#   1. name and surname is in lower case [C]

# %% [markdown]
# # TIDINESS
#
# - PATIENTS
#   1. phone and email together in conatct col
#
#
# - TREATMENTS
#   1. 3 varibales stored in novodra and auralin
#
#
# - ADVERSE REACTIONS
#   1. no point of using the table
#      (merge the adverse table to treatment table)

# %% [markdown]
#  # Completeness Issues
#
#    1. missing values for 12 patitents in contact details
#    2. only 280 rows are present instead of 350
#    3. hbalc_change col has missing values

# %%
# creating copies so that data can be accessed again even if their are problems in the further steps

# %%
patients_copy=patients.copy()
treatments_copy=treatments.copy()
adverse_reaction_copy=adverse_reaction.copy()

# %%
patients_copy[patients_copy['address'].isnull()]
# since there is no data present we can not proceed further for this table
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %% [markdown]
# # Define

# %%
# subtract hba1c_start from hba1c_end to get hba1c-change

# %% [markdown]
# # Code

# %%
treatments_copy['hba1c_change']=treatments_copy['hba1c_start']-treatments_copy['hba1c_end']

# %% [markdown]
# # Test

# %%
treatments_copy['hba1c_change'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 275    False
# 276    False
# 277    False
# 278    False
# 279    False
# Name: hba1c_change, Length: 280, dtype: bool

# %%
treatments_copy['hba1c_change'].isnull().sum()
# if sum is 0 then we can say that there are no missing values anymore
# Out:
# 0

# %%
treatments_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  280 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
treatments_copy.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    280.000000
# mean      7.985929    7.589286      0.396643
# std       0.568638    0.569672      0.060168
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.350000
# 50%       7.800000    7.420000      0.390000
# 75%       7.970000    7.570000      0.440000
# max       9.950000    9.580000      0.540000

# %% [markdown]
# # Tidiness Issues
#
#  1. phone and email together in conatct col
#  2. 3 varibales stored in novodra and auralin
#  3. no point of using the table (merge the adverse table to     treatment table)

# %% [markdown]
# # Define

# %%
# novodra and auralin using the melt function

# %% [markdown]
# # Code

# %%
treatments_copy
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0            0.43
# 1            0.47
# ...

# %%
#Commenting the below line since we have removed the dose column

# %%
#treatments_copy=treatments_copy[treatments_copy['dose']!='-']

# %%
#treatments_copy['start'],treatments_copy['end']=treatments_copy['dose'].str.split('-').str

# %%
#treatments_copy.drop(columns={'dose'},inplace=True)

# %% [markdown]
# # Test

# %%
treatments_copy
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0            0.43
# 1            0.47
# ...
